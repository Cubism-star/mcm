# %% [markdown]
# #  文本处理

# %%
import pandas as pd
import nltk
import wordcloud
from nltk.corpus import stopwords
import random
# %matplotlib inline

# %%
datas =pd.read_csv('microwave.tsv', sep='\t')

# %% [markdown]
# datas =pd.read_csv('pacifier.tsv', sep='\t')

# %% [markdown]
# datas =pd.read_csv('hair_dryer.tsv', sep='\t')

# %%
datas.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     21879631   RY52KZABZK8QF  B0052G14E8       423421857
# 1          US     14964566  R3GCOEV4HYZG2I  B0055UBB4O       423421857
# 2          US     13230389  R1V2OPPNL0QGCE  B0052G14E8       423421857
# 3          US     43655888   R9Q0QDTLKV567  B004ZU09QQ       423421857
# 4          US       117794  R3DL7HYC3QTWNI  B005GSZB7I       827502283
#
#                                        product_title  product_category  \
# 0              danby 0.7 cu.ft. countertop microwave  Major Appliances
# 1              danby 0.7 cu.ft. countertop microwave  Major Appliances
# 2              danby 0.7 cu.ft. countertop microwave  Major Appliances
# 3              danby 0.7 cu.ft. countertop microwave  Major Appliances
# 4  whirlpool stainless look countertop microwave,...  Major Appliances
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %% [markdown]
# # 文本合并 剔除停词 查看结果

# %% [markdown]
# good_review = [ str(datas['review_body'][i]) for i in range(len(datas)) if (datas['star_rating'][i]==5)]
#
# all_review = " ".join(good_review)
#
# datas['review_body'][0]
#
# tokens = nltk.word_tokenize(all_review)
#
# word_freq = nltk.FreqDist(tokens)
#
# filtered = {k:w for k,w in word_freq.items() if(k not in stopwords.words('english'))}
#
# filtered = [k for k,w in filtered.items() if(w >50)]
#
# string = " ".join(filtered)

# %%
数量 = 300

# %%
reviews = random.sample(list(datas['review_body']),数量)
reviews = " **** ".join(reviews)

# %%
reviews
# Out:
# "The template was completely wrong on where to put the screw holes on top, resulting in too many holes being drilled into the shelf above.  Other than that, this was a solid purchase. **** I purchased this item for two reasons, 1) because this is a Union Made microwave assembled in TN (the only American made microwave I've found)  and 2) It has a convection oven that can double as a 2nd oven.<br />The styling on this unit is very nice, sleek and not overcomplicated, it enhances the look of my kitchen.<br />The microwave cooking is simple, with built in functions for thawing frozen items or popping popcorn, etc.  You punch a button, it asks you how many steaks you are defrosting or how much popcorn you are popping and it does the rest.<br />Convection cooking is new to me, but the manual and recipe booklet that come with the unit have already produced salmon steaks with a white wine/basil sauce and cooked a pizza.  I've found that in the heat of the summer I can use this oven vs. my g
# ...

# %%
tokens = nltk.word_tokenize(reviews)

# %%
tokens_expect_stopword =[w for w in tokens if (w.lower() not in stopwords.words('english'))]

# %%
my_stopword = [',','>','<','/','br','(','would',')','#','&','microwave',';',"'s",'.','!',':','...','?']

# %%
with open('long_stopwords.txt','r') as f:
    t = f.read()

# %%
my_stopword = my_stopword+t.split('\n')

# %%
tokens_expect_stopword = [w for w in tokens_expect_stopword if (w.lower() not in my_stopword)]

# %%
string = " ".join(tokens_expect_stopword)

# %%
word_freq=nltk.FreqDist(tokens_expect_stopword)

# %%
word_freq.most_common(100)
# Out:
# [('****', 299),
#  ('unit', 92),
#  ('great', 86),
#  ('door', 63),
#  ('oven', 62),
#  ('well', 60),
#  ('time', 56),
#  ('product', 55),
#  ('$', 51),
#  ('small', 49),
#  ('years', 48),
#  ('GE', 47),
#  ('space', 47),
#  ('service', 47),
#  ('34', 46),
#  ('good', 45),
#  ('kitchen', 45),
#  ('2', 43),
#  ('works', 43),
#  ('-', 43),
#  ('problem', 43),
#  ('bought', 41),
#  ('cooking', 40),
#  ("'m", 40),
#  ('easy', 39),
#  ('paint', 36),
#  ('top', 35),
#  ('Sharp', 35),
#  ('buy', 35),
#  ('purchase', 34),
#  ('year', 34),
#  ('months', 32),
#  ('counter', 32),
#  ('cabinet', 31),
#  ('Samsung', 30),
#  ('model', 30),
#  ('working', 29),
#  ('nice', 28),
#  ('button', 27),
#  ('price', 27),
#  ('perfect', 27),
#  ('fit', 27),
#  ('Whirlpool', 27),
#  ('warranty', 27),
#  ('work', 27),
#  ('purchased', 26),
#  ('worked', 26),
#  ('food', 25),
#  ('quality', 25),
#  ('open', 25),
#  ('range', 24),
#  ('replacement', 24),
#  ('convection', 22),
#  ('needed', 22),
# ...

# %%
all_tokens = []
for k,sentence in enumerate(string.split('****')):
    all_tokens.append(nltk.word_tokenize(sentence))

# %%
len(all_tokens)
# Out:
# 300

# %%
# 周玮康 3017207087

def scanData(D, ck, minsupport=0.8,maxsupport=0.9):
    dict = {}
    for c in ck:
        for items in D:
            # 集合的函数 可以用来判断是否是子集**
            if c.issubset(items):
                if c in dict:
                    # 字典中可以用set做key **
                    dict[c] += 1
                else:
                    dict[c] = 1
    relist = []
    support = {}  # 每个数据值的支持度
    # 可以for遍历字典得到key值
    for key in dict:
        if dict[key] / len(D) >= minsupport and dict[key] / len(D) <= maxsupport :
            relist.append(key)
        support[key] = round(dict[key] / len(D), 6)
    return relist, support

# %%
def apriorigen(DS):
    retlist = []
    lenLk = len(DS)
    for i in range(lenLk):
        for j in range(i + 1, lenLk):
            if len(DS[i] | DS[j]) - len(DS[i]) == 1:
                if not DS[i] | DS[j] in retlist:
                    retlist.append(DS[i] | DS[j])
    return retlist

# %%
# 判断在fre 大集合中， 每个元素组合的关系是否符合conf >= minconf
def conf(fre, H, supportData, brl, minconf=0.7):
    # 用来记录这个元素已经被推断过
    pruneH = []
    for element in H:
        conf = round(supportData[fre] / supportData[fre - element], 2)
        if conf >= minconf:
            print(fre - element, '==>', element, ' :conf = ', conf)
            brl.append([fre - element, fre, conf])
            pruneH.append(element)
    return pruneH

# %%
# 用于使用候选规则对关联规则计算做剪枝
# 规则： 若左部为{0，1，2}=>{3}不满足conf 则 左部为{1，2，0}子集的也不会满足 因为子集的支持度增大，即出现的概率增大，而分子概率不变
# 即 conf = $\frac{X U Y}{X}$
def rulesFromConseq(fre, H, supportData, brl, minconf):
    # 获取每个集合的元素个数，即i
    # H为出现在规则右边的集合的列表，判断目前打算用来做子集合中元素的个数
    m = len(H[0])
    # 满足 比子集 大 2 才有合并的必要 ，见5行后的注释详细解释
    if len(fre) > (m + 1):
        # 生成H中元素无重复组合
        Hmp1 = apriorigen(H)
        # e.g. 假如为第一次进入，则每个Hmp1中只有大小为1的子集合，经上步当生成后获得大小为2的子集合
        # 并将一个大小为2的支持度符合的值子集合传回，为下次递归生成 3元素子集合做准备，直到发现子集的个数+2的子集与全集相等停止
        Hmp1 = conf(fre, Hmp1, supportData, brl, minconf)
        if (len(Hmp1) > 1):
            # 递归
            rulesFromConseq(fre, Hmp1, supportData, brl, minconf)

# %%
'''
总思路：
    首先求单个元素，计算每个元素支持值，判断是否保留
    用单元素集求双元素候选集
    计算每个元素支持值，判断是否保留
    继续计算候选值
    计算支持值
    ……
    直到由于支持值将所有集合内元素抛出
    结束循环
'''
dataSet = all_tokens
# 将数据转化成字典 单转map无法直观看出， 无需遍历，直接list即可
D = list(map(set, dataSet))

# 求取无重复的不变集合
# 使用‘[]’能够保证元素不散 ***很重要
singleSet = []
for items in dataSet:
    for item in items:
        if not [item] in singleSet:
            singleSet.append([item])
print(singleSet)
# Out:
# [['template'], ['completely'], ['wrong'], ['screw'], ['holes'], ['top'], ['drilled'], ['shelf'], ['solid'], ['purchase'], ['purchased'], ['item'], ['reasons'], ['1'], ['Union'], ['assembled'], ['TN'], ['American'], ['2'], ['convection'], ['oven'], ['double'], ['2nd'], ['.'], ['styling'], ['unit'], ['nice'], ['sleek'], ['overcomplicated'], ['enhances'], ['kitchen'], ['cooking'], ['simple'], ['built'], ['functions'], ['thawing'], ['frozen'], ['items'], ['popping'], ['popcorn'], ['punch'], ['button'], ['asks'], ['steaks'], ['defrosting'], ['rest'], ['Convection'], ['manual'], ['recipe'], ['booklet'], ['produced'], ['salmon'], ['white'], ['wine/basil'], ['sauce'], ['cooked'], ['pizza'], ['heat'], ['summer'], ['vs.'], ['gas'], ['cooks'], ['faster'], ['house'], ['function'], ['combines'], ['meals'], ['things'], ['machine'], ['figure'], ['out'], ['feature'], ['turn'], ['turntable'], ['on/off'], ['depending'], ['round'], ['rectangular'], ['dish'], ['runs'], ['regular'], ['110'], ['voltage'],
# ...

# %%
C1 = list(map(frozenset, singleSet))
support_Value_min = 1/数量 *5
support_Value_max = 1/数量 *20
supportData = {}
L1, t = scanData(D, C1,support_Value_min,support_Value_max)
supportData.update(t)
L = [L1]
k = 1
while (len(L[k - 1]) > 0):
    Ck = apriorigen(L[k - 1])
    Lk, t = scanData(D, Ck,support_Value_min,support_Value_max)
    supportData.update(t)  # 更新字典（把新出现的集合:支持度加入到supportData中）
    L.append(Lk)
    k += 1

print(supportData)
print(L)
# Out:
# {frozenset({'template'}): 0.01, frozenset({'completely'}): 0.016667, frozenset({'wrong'}): 0.016667, frozenset({'screw'}): 0.013333, frozenset({'holes'}): 0.01, frozenset({'top'}): 0.09, frozenset({'drilled'}): 0.006667, frozenset({'shelf'}): 0.013333, frozenset({'solid'}): 0.006667, frozenset({'purchase'}): 0.096667, frozenset({'purchased'}): 0.076667, frozenset({'item'}): 0.043333, frozenset({'reasons'}): 0.003333, frozenset({'1'}): 0.043333, frozenset({'Union'}): 0.003333, frozenset({'assembled'}): 0.003333, frozenset({'TN'}): 0.003333, frozenset({'American'}): 0.003333, frozenset({'2'}): 0.1, frozenset({'convection'}): 0.04, frozenset({'oven'}): 0.126667, frozenset({'double'}): 0.003333, frozenset({'2nd'}): 0.006667, frozenset({'.'}): 0.153333, frozenset({'styling'}): 0.003333, frozenset({'unit'}): 0.16, frozenset({'nice'}): 0.076667, frozenset({'sleek'}): 0.01, frozenset({'overcomplicated'}): 0.003333, frozenset({'enhances'}): 0.003333, frozenset({'kitchen'}): 0.136667, frozense
# ...

# %%
# 求出关联组合 并且每次剪枝
brl = []
minconf = 0.4
# 从二元素集合开始遍历总集合
for i in range(1, len(L)):
    # 遍历所有二元素集合 fre为每个子选课集合
    for fre in L[i]:
        # 获得每个fre中的所有单个元素
        H = [frozenset([item]) for item in fre]
        if i > 1:
            # 由于fre中元素种类变多，需要做分割,使用候选规则
            rulesFromConseq(fre, H, supportData, brl, minconf)
        else:
            conf(fre, H, supportData, brl, minconf)

print(brl)
# Out:
# frozenset({'convection'}) ==> frozenset({'Samsung'})  :conf =  0.42
# frozenset({'convection'}) ==> frozenset({'Sharp'})  :conf =  0.42
# frozenset({'seconds'}) ==> frozenset({'cooking'})  :conf =  0.45
# frozenset({'high'}) ==> frozenset({'items'})  :conf =  0.5
# frozenset({'items'}) ==> frozenset({'high'})  :conf =  0.5
# frozenset({'high'}) ==> frozenset({'feature'})  :conf =  0.5
# frozenset({'help'}) ==> frozenset({'Sharp'})  :conf =  0.86
# frozenset({'repair'}) ==> frozenset({'model'})  :conf =  0.43
# frozenset({'week'}) ==> frozenset({'last'})  :conf =  0.46
# frozenset({'last'}) ==> frozenset({'week'})  :conf =  0.43
# frozenset({'steel'}) ==> frozenset({'appliances'})  :conf =  0.56
# frozenset({'stainless'}) ==> frozenset({'appliances'})  :conf =  0.64
# frozenset({'corner'}) ==> frozenset({'fits'})  :conf =  0.63
# frozenset({'paint'}) ==> frozenset({'inside'})  :conf =  0.41
# frozenset({'dinner'}) ==> frozenset({'plate'})  :conf =  0.86
# ...
